# %%
# Strin Data Structure


#' ' / " " -- single line string 
#''' / """ -- multi line string

# %%
p = "python"

# %%
p = 'python is scripting as well interpreter lang,it's also use in ML'
# Out:
#   Cell In[71], line 1
#     p = 'python is scripting as well interpreter lang,it's also use in ML'
#                                                                          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
p = "python is scripting as well interpreter lang,it's also use in ML"

# %%
p = "python is scripting as well "interpreter" lang,its also use in ML"
# Out:
#   Cell In[73], line 1
#     p = "python is scripting as well "interpreter" lang,its also use in ML"
#                                       ^
# SyntaxError: invalid syntax

# %%
p = '''python is scripting as' well' "interpreter" lang,its also use in ML'''

# %%
p = 'python'

# %%
print(p)
# Out:
# python is scripting as' well' "interpreter" lang,its also use in ML

# %%
p = '''This example shows version 2.1 of the event notification JSON structure. 
Amazon S3 uses versions 2.1, 2.2, and 2.3 of this event structure. Amazon S3 uses 
version 2.2 for cross-Region replication event notifications. It uses version 2.3 for 
S3 Lifecycle, S3 Intelligent-Tiering, object ACL, object tagging, and object restoration 
delete events. These versions contain extra information specific to these operations. 
Versions 2.2 and 2.3 are otherwise compatible with version 2.1, 
which Amazon S3 currently uses for all other event notification types.'''

# %%
print(p)
# Out:
# This example shows version 2.1 of the event notification JSON structure.
# Amazon S3 uses versions 2.1, 2.2, and 2.3 of this event structure. Amazon S3 uses
# version 2.2 for cross-Region replication event notifications. It uses version 2.3 for
# S3 Lifecycle, S3 Intelligent-Tiering, object ACL, object tagging, and object restoration
# delete events. These versions contain extra information specific to these operations.
# Versions 2.2 and 2.3 are otherwise compatible with version 2.1,
# which Amazon S3 currently uses for all other event notification types.

# %%
#5/10/25
p = 'python'

# %%
p.upper()
# Out:
# 'PYTHON'

# %%
p = 'JAVA'

# %%
p.lower()
# Out:
# 'java'

# %%
p= 'the python world'

# %%
p.capitalize()
# Out:
# 'The python world'

# %%
p.title()
# Out:
# 'The Python World'

# %%
p='shubham chinchole'

# %%
p.title()
# Out:
# 'Shubham Chinchole'

# %%
p = 'PyThOn'

# %%
# it will change small to capital and capital to samll ex: a -> A | A -> a
p.swapcase()
# Out:
# 'pYtHoN'

# %%
p = 'safdkjibsdfuysdvfuvsdufs'

# %%
p.count('s')
# Out:
# 5

# %%
p = 'python is use for DE ans python is also use for ML'

# %%
p.count('python')
# Out:
# 2

# %%
p.index('a')
# Out:
# 12

# %%
#IMP:

#startswith(substring)
#endswith(substring)

#it will alway return true or false

# %%
p = 'copper_daily_2025.csv'

# %%
p.startswith('copper')
# Out:
# True

# %%
p.startswith('co')
# Out:
# True

# %%
email = 'test@gmail.com'

# %%
email.endswith('@gmail.com')
# Out:
# True

# %%
p
# Out:
# 'copper_daily_2025.csv'

# %%
# find it will return the index of string starting  position
# if string not found then it will return -1


p.find('2026')
# Out:
# -1

# %%
if p.find('2025')==-1:
    print("not found")
else:
    print("found")
# Out:
# found

# %%
p = 'python'

# %%
p.replace('p' ,'J')
# Out:
# 'Jython'

# %%
#if multiple occurance of char/ word in given string then it will replace all occurance
#if we want only 1st occurance change then we have to give number of that occurance 

p = 'pythonpppptest'

p.replace('p','J',1)
# Out:
# 'Jythonpppptest'

# %%
p = 'PX-PX232434'

p.replace('PX-','')
# Out:
# 'PX232434'

# %%
p.replace('PX-PX','')
# Out:
# '232434'

# %%
# we can replace white space 
p = 'the sdf gfd asd gfsd '
p.replace(' ','')
# Out:
# 'thesdfgfdasdgfsd'

# %%
email
# Out:
# 'test@gmail.com'

# %%
# we can split the string using some delimeter / char/ word /space
# it will alway give output in list 
email.split('@')[0]
# Out:
# 'test'

# %%
p
# Out:
# 'the sdf gfd asd gfsd '

# %%
p='copper_daily_2025.csv'

# %%
p.split('_')
# Out:
# ['copper', 'daily', '2025.csv']

# %%
p.split('_')[-1]
# Out:
# '2025.csv'

# %%
p.split('_')[-1].split('.')[0]
# Out:
# '2025'

# %%
p = '  admin  '

# %%
#strip - both end
#lstrip - left end
#rstrip - right end


p.strip()
# Out:
# 'admin'

# %%
p.lstrip()
# Out:
# 'admin  '

# %%
p.rstrip()
# Out:
# '  admin'

# %%
a  =10
b =40
c = a+b
print(c)
# Out:
# 50

# %%
# How to take input dfrom user :

x = int(input("Enter the number:"))
# Out:
# Enter the number: 200

# %%
x
# Out:
# 200

# %%
#How to insert dynamic content into string
# using format method

a = 100
b = 200
c = a+b

"Addition of 100 and 200 is 300"


"Addition of {} and {} is  {}".format(a,b,c)
# Out:
# 'Addition of 100 and 200 is  300'

# %%
#That is called an f-string in Python  // raw string
#Formatted String Literal

f"Addition of {a} and {b} is {c}"
# Out:
# 'Addition of 100 and 200 is 300'

# %%
'insert into emp values({},{},{})'.format(101,'keshav','pune')
# Out:
# 'insert into emp values(101,keshav,pune)'

# %%
# read csv file

import csv
with open("C:/Users/SHUBHAM/Downloads/employee_records.csv") as fp:
    r= csv.DictReader(fp)
    for row in r:
        st = "insert into emp values({},'{}','{}')".format(row['eid'],row['ename'],row['emailid'])
        print(st)
# Out:
# insert into emp values(101,'Riya Patel','riya.patel1@example.com')
# insert into emp values(102,'Aakash Bansal','aakash.bansal2@outlook.com')
# insert into emp values(103,'Kunal Mishra','kunal.mishra3@outlook.com')
# insert into emp values(104,'Kiran Gupta','kiran.gupta4@yahoo.com')
# insert into emp values(105,'Anita Gupta','anita.gupta5@hotmail.com')
# insert into emp values(106,'Sara Bansal','sara.bansal6@example.com')
# insert into emp values(107,'Ishita Sharma','ishita.sharma7@yahoo.com')
# insert into emp values(108,'Kiran Mishra','kiran.mishra8@gmail.com')
# insert into emp values(109,'Simran Gupta','simran.gupta9@hotmail.com')
# insert into emp values(110,'Dev Yadav','dev.yadav10@example.com')
# insert into emp values(111,'Rahul Smith','rahul.smith11@example.com')
# insert into emp values(112,'Priya Patel','priya.patel12@yahoo.com')
# insert into emp values(113,'Dev Verma','dev.verma13@example.com')
# insert into emp values(114,'Riya Verma','riya.verma14@yahoo.com')
# ...

# %%
p = 'python'

# %%
p.isalpha()
# Out:
# True

# %%
p = '565656'

# %%
p.isnumeric()
# Out:
# True

# %%
p='dbjhsdswhjdjfww54'

# %%
p.isalnum()
# Out:
# True

# %%
p= 'ddddwdq!@#$%^&*((())(*&^%$#@!255JJJ'

# %%
#to find special char only form string

for char in p:
    if not char.isalnum():
        print(char,end='')
# Out:
# !@#$%^&*((())(*&^%$#@!

# %%
#Type casting

#int -> str 

p = 10

# %%
str(p)
# Out:
# '10'

# %%
#Type casting

#str -> int 
# for this we have to use numeric in str to type cast alpha numeric give error/ not possible

p = '10'

# %%
int(p)
# Out:
# 10

# %%
#Type casting

#float -> int 

p = 22.6

# %%
int(p)
# Out:
# 22

# %%
#Type casting

#int -> float

p =22.6

# %%
float(p)
# Out:
# 22.6

# %%
# type cast into int
#first we have to type cast in float and then in int

p = '23.3'

# %%
int(float(p))
# Out:
# 23

# %%
#Type cast data structure

#list -> tuple

p=[1,2,3,4,5]

# %%
tuple(p)
# Out:
# (1, 2, 3, 4, 5)

# %%
#Type cast data structure

#tuple -> list

# %%
p = (4,5,6,7,8)

# %%
list(p)
# Out:
# [4, 5, 6, 7, 8]

# %%
# if you have add element in tuple which in immutable 
# the 1st type cast in list and append value in list 
# then again type cast list in tuple

p = (1,2,3,4,5,6)

# %%
li = list(p)

# %%
li.extend([7,8,9])

# %%
p= tuple(li)

# %%
p
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
# to remove duplicate element using type cast

p = [45,86,34,75,23,75,3,76,43,75,6]

# %%
# it will remove duplicate but element are un ordered

set(p)
# Out:
# {3, 6, 23, 34, 43, 45, 75, 76, 86}

# %%
# to maintain the order as its of result of set then we can use list type cast on set
list(set(p))
# Out:
# [34, 3, 6, 75, 76, 45, 43, 86, 23]

# %%
#Type cast data structure

#dict -> list

emp = {'a':100,'b':200,'c':300}

# %%
list(emp)
# Out:
# ['a', 'b', 'c']

# %%
#dict -> tuple

tuple(emp)
# Out:
# ('a', 'b', 'c')

# %%
# to get only values from dict 

list(emp.values())
# Out:
# [100, 200, 300]

# %%
# to get only items from dict 

list(emp.items())
# Out:
# [('a', 100), ('b', 200), ('c', 300)]

# %%
#Operators:

# Arithmetic Operators
# Comparison (Relational) Operators
# Logical Operators
# Bitwise Operators
# Assignment Operators
# Membership Operators
# Identity Operators
# Ternary Operator

# %%
# Arithmetic Operators
# + /Addition will add homogenus element 

# ex: addition of two list

[1,2,3] + [4,5,6]


# it will concat both list in one
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# ex: addition of two tuple

(1,2,3)+(4,5,6)

# it will concat both tuple in one
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
p = 'python'

# %%
p*3

# it will repeat the string
# Out:
# 'pythonpythonpython'

# %%
[1,2,3]*3

# it consider whole list as single object and then repeat it 3 times
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
{1,2,3}*3

#unordered collections  don’t support repetition or indexing.
# if you want repetition of element then 1st type cast the set into list or tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 {1,2,3}*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
# Floor Division

# it will always give lowest value of result


5//2
# Out:
# 2

# %%
# to us ceiling  we have to import math module
# it alway give upper value in result

import math
math.ceil(5/2)
# Out:
# 3

# %%
filename = 'copper_daily.csv'

# %%
filename.startswith('cop') and filename.endswith('.csv')
# Out:
# True

# %%
filename.startswith('sop') and filename.endswith('.csv')
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
# to find a element in ds we can use in operator / find() but in more usefull

p = [34,786,34,7634,755,5,75,6546]

# %%
5 in  p
# Out:
# True

# %%
# in operator will work in string also

p = 'sdfkjbsdf sdfjkdsfsdfikusdbfsd fsdfkjsdbfsdjhuvfsdjkh 100'

# %%
'100' in p
# Out:
# True

# %%
p = 'copper_daily_2025_prd.csv'

# %%
#to get 2025

'2025' in p
# Out:
# True

# %%
emp
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
100 in emp.values()
# Out:
# True

# %%
100 not in emp.values()
# Out:
# False

# %%
print("priya")

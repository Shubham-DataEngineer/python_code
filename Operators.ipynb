# %%
#Operators:

# Arithmetic Operators
# Comparison (Relational) Operators
# Logical Operators
# Bitwise Operators
# Assignment Operators
# Membership Operators
# Identity Operators
# Ternary Operator

# %%
# Arithmetic Operators
# + /Addition will add homogenus element 

# ex: addition of two list

[1,2,3] + [4,5,6]


# it will concat both list in one
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# ex: addition of two tuple

(1,2,3)+(4,5,6)

# it will concat both tuple in one
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
p = 'python'

# %%
p*3

# it will repeat the string
# Out:
# 'pythonpythonpython'

# %%
[1,2,3]*3

# it consider whole list as single object and then repeat it 3 times
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
{1,2,3}*3

#unordered collections  don’t support repetition or indexing.
# if you want repetition of element then 1st type cast the set into list or tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 {1,2,3}*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
# Floor Division

# it will always give lowest value of result


5//2
# Out:
# 2

# %%
# Comparison (Relational) Operators

a = 10
b = 20

print(a == b)   # False
print(a != b)   # True
print(a > b)    # False
print(a < b)    # True
print(a >= 10)  # True
print(b <= 15)  # False
# Out:
# False
# True
# False
# True
# True
# False

# %%
# Logical Operators
filename = 'copper_daily.csv'

# %%
# to us ceiling  we have to import math module
# it alway give upper value in result

import math
math.ceil(5/2)
# Out:
# 3

# %%
filename.startswith('cop') and filename.endswith('.csv')
# Out:
# True

# %%
filename.startswith('sop') and filename.endswith('.csv')
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
#Membership Operators (in , not in)
# to find a element in ds we can use in operator / find() but in more usefull

p = [34,786,34,7634,755,5,75,6546]

# %%
5 in  p
# Out:
# True

# %%
# in operator will work in string also

p = 'sdfkjbsdf sdfjkdsfsdfikusdbfsd fsdfkjsdbfsdjhuvfsdjkh 100'

# %%
'100' in p
# Out:
# True

# %%
p = 'copper_daily_2025_prd.csv'

# %%
#to get 2025

'2025' in p
# Out:
# True

# %%
emp
# Out:
# {'a': 100, 'b': 200, 'c': 300}

# %%
100 in emp.values()
# Out:
# True

# %%
100 not in emp.values()
# Out:
# False

# %%
# Assignment Operators

a = 10
b = 20

# %%
# Identity Operators (is,not is)
# it is memory based comparison

# is vs ==
# is -- memory based comparision
# == - value based comparision

a = 10

# %%
b = 10

# %%
id(a)
# Out:
# 140706814604488

# %%
id(b)
# Out:
# 140706814604488

# %%
# both a and b has same memory address because it is in 8 bit
# only one value 10 in memory created , aand b both point/reffred  to same memory address

# %%
a = 50000

# %%
b = 50000

# %%
id(a)
# Out:
# 1663827378768

# %%
id(b)
# Out:
# 1663827393680

# %%
# both a and b have diffrent memory address because it is more than 8 bit in memory and 
# it will spread into diffrent block in memory
# both execution time is diffrent also

# %%
a = b = 50000

# %%
id(a)
# Out:
# 1663827393904

# %%
id(b)
# Out:
# 1663827393904

# %%
# both a and b has same memory address because the exceution time of both in memory at same time

# %%
a
b
# Out:
# 50000

# %%
a = 10

# %%
b = 10

# %%
# is used for memory based comparison 
a is b
# Out:
# True

# %%
# == it is use for value based comparison
a == b
# Out:
# True

# %%
# Bitwise Operators (&,|)
# it use bitwsie opreation

# binary -> 2
# decimal -> 10
# octal -> 8
# hexa decimmal ->16


#here logical and is also used
25 & 15
# Out:
# 9

# %%
# to find binary of any number
# don't consider the first two digit base(2)
bin(25)
# Out:
# '0b11001'

# %%
# to find decimal of binary
# first give binary and base value

int('1111',2)
# Out:
# 15

# %%
#bitwise | (or)
#here logical or is also used
20 | 5
# Out:
# 21

# %%
# simple if


# if condition:
#     block of statements


# no braces are use instead python use indentation/space(By default, indentation is 4 spaces)

# %%
# simple if 

age = int(input("Enter the age:"))
if age>=18:
    print("You can vote")
print("thanks")
# Out:
# Enter the age: 12
# thanks

# %%
print("1")
print("2")
print("3")
a = 5
if a>10:
    print("4")
    print("5")
print("6")
# Out:
# 1
# 2
# 3
# 6

# %%
#if -else - two condition

# if condition:
#     block of statement
# else:
#     block of statement


# both conditon are diffrent 
# only one is true at a time

# %%
# if - else

num = int(input("Enter the number:"))
if num%2==0:
    print("{} is even number".format(num))
else:
    print(f"{num} is odd")
# Out:
# Enter the number: 22
# 22 is even number

# %%
# Assignment 
# email id
# filename
# product should contain 2025 year
# file startswith copper and should contain 2025 should be pdf

# %%
# email id

email_id = input("Enter email id:")

if "@" in email_id and ".com" in email_id :
    print("It is a vaild email id")
else:
    print("Invaild email id")
# Out:
# Enter email id: shubham@.con
# Invaild email id

# %%
# filename

filename=input("Enter file name:")

if "copper" in filename:
    print("File found")
else:
    print("File not found")
# Out:
# Enter file name: copper
# File found

# %%
# product should contain 2025 year


product = input("Enter product name or code: ")

if product.find("2025") != -1:        
    print("Product is from year 2025")
else:
    print("Product is not from year 2025")
# Out:
# Enter product name or code:  nn_2025_2025jn
# Product is from year 2025

# %%
# file startswith copper and should contain 2025 should be pdf

filename=input("Enter file name:")

if filename.startswith("copper") and filename.find("2025") != -1 and filename.endswith(".pdf"):
    print("File found")
else:
    print("File not found")
# Out:
# Enter file name: copper_solution_2025545.pdf
# File found

# %%
new message by sahil whoch cant be commited

# %%
event={'Records': [{'EventSource': 'aws:sns', 'EventVersion': '1.0', 'EventSubscriptionArn': 'arn:aws:sns:ap-south-1:254845684171:upload-sns:d60fc16c-234f-48dd-846f-1b4e44f8ee8c', 'Sns': {'Type': 'Notification', 'MessageId': '8dbdd3d3-b346-5675-afc2-b214bebd346b', 'TopicArn': 'arn:aws:sns:ap-south-1:254845684171:upload-sns', 'Message': '{"Records":[{"eventVersion":"2.1","eventSource":"aws:s3","awsRegion":"ap-south-1","eventTime":"2025-12-25T10:02:34.258Z","eventName":"ObjectCreated:Put","userIdentity":{"principalId":"A3ETGP9PPEB2B1"},"requestParameters":{"sourceIPAddress":"123.201.214.141"},"responseElements":{"x-amz-request-id":"3ZT6C5MA3BM1FJNW","x-amz-id-2":"bEz3FH6B1/3agn8gOLsnTYruHZDKDiD4JerskzXVjLbiBaMT6prJ2EEKQQnpu9Pnmblrn6zINZTqm4C+0vSEkfZ4c0v/FMeV8KyHyax04Rw="},"s3":{"s3SchemaVersion":"1.0","configurationId":"upload-sns-email","bucket":{"name":"demo-offline8","ownerIdentity":{"principalId":"A3ETGP9PPEB2B1"},"arn":"arn:aws:s3:::demo-offline8"},"object":{"key":"silve_data_final.txt","size":2493,"eTag":"33d2cfaec68b05f5e94096c69a5995ac","versionId":"Wplr30bTT7XqLg1lAru54RDnoqYbSDiT","sequencer":"00694D0BBA392267C0"}}}]}', 'Timestamp': '2025-12-25T10:02:35.230Z', 'SignatureVersion': '1', 'Signature': '', 'SigningCertUrl': 'https://sns.ap-south-1.amazonaws.com/SimpleNotificationService-7506a1e35b36ef5a444dd1a8e7cc3ed8.pem', 'Subject': 'Amazon S3 Notification', 'UnsubscribeUrl': 'https://sns.ap-south-1.amazonaws.com/?Action=Unsubscribe&SubscriptionArn=arn:aws:sns:ap-south-1:254845684171:upload-sns:d60fc16c-234f-48dd-846f-1b4e44f8ee8c', 'MessageAttributes': {}}}]}

# %%
event
# Out:
# {'Records': [{'EventSource': 'aws:sns',
#    'EventVersion': '1.0',
#    'EventSubscriptionArn': 'arn:aws:sns:ap-south-1:254845684171:upload-sns:d60fc16c-234f-48dd-846f-1b4e44f8ee8c',
#    'Sns': {'Type': 'Notification',
#     'MessageId': '8dbdd3d3-b346-5675-afc2-b214bebd346b',
#     'TopicArn': 'arn:aws:sns:ap-south-1:254845684171:upload-sns',
# ...

# %%
import json

bucketname=json.loads(event['Records'][0]['Sns']['Message'])['Records'][0]['s3']['bucket']['name']
filename=json.loads(event['Records'][0]['Sns']['Message'])['Records'][0]['s3']['object']['key']

# %%
print(bucketname)
# Out:
# demo-offline8

# %%
print(filename)
# Out:
# silve_data_final.txt

# %%
event={'Records': [{'messageId': '5a35f975-b473-439f-ba5d-12a6e8895936', 'receiptHandle': '...', 'body': '{\n  "Type" : "Notification",\n  "MessageId" : "97f996dd-b98f-5d7c-89e6-f71aad8133bf",\n  "TopicArn" : "arn:aws:sns:ap-south-1:254845684171:upload-sns",\n  "Subject" : "Amazon S3 Notification",\n  "Message" : "{\\"Records\\":[{\\"eventVersion\\":\\"2.1\\",\\"eventSource\\":\\"aws:s3\\",\\"awsRegion\\":\\"ap-south-1\\",\\"eventTime\\":\\"2025-12-25T10:28:29.778Z\\",\\"eventName\\":\\"ObjectCreated:Put\\",\\"userIdentity\\":{\\"principalId\\":\\"A3ETGP9PPEB2B1\\"},\\"requestParameters\\":{\\"sourceIPAddress\\":\\"123.201.214.141\\"},\\"responseElements\\":{\\"x-amz-request-id\\":\\"CDDDKV6CS27SYN7X\\",\\"x-amz-id-2\\":\\"Mt58d0QoFfIeFG50vxhcT/sEDeSKVcT5YVtfX73iR01OqitKYMlW0MClIJ4x+h2WJaR/86ae2dwhDRjt1wDbFedYIxweeTJOcslqr0w7Q3c=\\"},\\"s3\\":{\\"s3SchemaVersion\\":\\"1.0\\",\\"configurationId\\":\\"sns-sqs\\",\\"bucket\\":{\\"name\\":\\"demo-offline8\\",\\"ownerIdentity\\":{\\"principalId\\":\\"A3ETGP9PPEB2B1\\"},\\"arn\\":\\"arn:aws:s3:::demo-offline8\\"},\\"object\\":{\\"key\\":\\"Untitled1.ipynb\\",\\"size\\":6400,\\"eTag\\":\\"1b6dcf28ba7f6f83838efb0e383d88f4\\",\\"versionId\\":\\"Pvpj69OYh7I2iuYF72mYiEFuYFZR4811\\",\\"sequencer\\":\\"00694D11CDBC94D384\\"}}}]}",\n  "Timestamp" : "2025-12-25T10:28:30.468Z",\n  "SignatureVersion" : "1",\n  "Signature" : "",\n  "SigningCertURL" : "https://sns.ap-south-1.amazonaws.com/SimpleNotificationService-7506a1e35b36ef5a444dd1a8e7cc3ed8.pem",\n  "UnsubscribeURL" : "https://sns.ap-south-1.amazonaws.com/?Action=Unsubscribe&SubscriptionArn=arn:aws:sns:ap-south-1:254845684171:upload-sns:86c5cd0c-635c-469f-9e91-3a28e901e709"\n}', 'attributes': {'ApproximateReceiveCount': '7', 'SentTimestamp': '1766658510502', 'SenderId': 'AIDAJKTPXYYAO6CI6DPKS', 'ApproximateFirstReceiveTimestamp': '1766658510509'}, 'messageAttributes': {}, 'md5OfBody': 'fa23b130134eb145743c112a3e5e3d9a', 'eventSource': 'aws:sqs', 'eventSourceARN': 'arn:aws:sqs:ap-south-1:254845684171:sns-sqs', 'awsRegion': 'ap-south-1'}]}

# %%
event
# Out:
# {'Records': [{'messageId': '5a35f975-b473-439f-ba5d-12a6e8895936',
#    'receiptHandle': '...',
# ...

# %%
import json

json.loads(event['Records'][0]['body']['Message'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import json
# ----> 3 json.loads(event['Records'][0]['body']['Message'])
#
# TypeError: string indices must be integers, not 'str'

# %%
import json
filename = json.loads(json.loads(event['Records'][0]['body'])['Message'])['Records'][0]['s3']['object']['key']

# %%
filename
# Out:
# 'Untitled1.ipynb'
